# %%
import seaborn as sns 
df=sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df['time'].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
## feautre encoding (label encoiding and onehot encodinh )

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
x=df[['tip', 'sex', 'smoker', 'day', 'time', 'size']]
y=df['total_bill']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25, random_state=42)

# %%
x_train
# Out:
#       tip     sex smoker  day    time  size
# 115  3.50  Female     No  Sun  Dinner     2
# 181  5.65    Male    Yes  Sun  Dinner     2
# 225  2.50  Female    Yes  Fri   Lunch     2
# 68   2.01    Male     No  Sat  Dinner     2
# 104  4.08  Female     No  Sat  Dinner     2
# ..    ...     ...    ...  ...     ...   ...
# 106  4.06    Male    Yes  Sat  Dinner     2
# 14   3.02  Female     No  Sun  Dinner     2
# 92   1.00  Female    Yes  Fri  Dinner     2
# 179  3.55    Male    Yes  Sun  Dinner     2
# 102  2.50  Female    Yes  Sat  Dinner     3
#
# [183 rows x 6 columns]

# %%
##feature encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le1=LabelEncoder()
le2=LabelEncoder()
le3=LabelEncoder()

# %%
x_train['sex']=le1.fit_transform(x_train['sex'])
x_train['smoker']=le2.fit_transform(x_train['smoker'])
x_train['time']=le3.fit_transform(x_train['time'])

# %%
x_train.head()
# Out:
#       tip  sex  smoker  day  time  size
# 115  3.50    0       0  Sun     0     2
# 181  5.65    1       1  Sun     0     2
# 225  2.50    0       1  Fri     1     2
# 68   2.01    1       0  Sat     0     2
# 104  4.08    0       0  Sat     0     2

# %%
x_test['sex']=le1.transform(x_test['sex'])
x_test['smoker']=le2.transform(x_test['smoker'])
x_test['time']=le3.transform(x_test['time'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 x_test['sex']=le1.transform(x_test['sex'])
#       2 x_test['smoker']=le2.transform(x_test['smoker'])
#       3 x_test['time']=le3.transform(x_test['time'])
#
# File /opt/homebrew/Cellar/jupyterlab/4.4.7/libexec/lib/python3.13/site-packages/sklearn/preprocessing/_label.py:139, in LabelEncoder.transform(self, y)
#     137 check_is_fitted(self)
#     138 xp, _ = get_namespace(y)
# --> 139 y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
#     140 # transform of empty array is empty array
#     141 if _num_samples(y) == 0:
#
# File /opt/homebrew/Cellar/jupyterlab/4.4.7/libexec/lib/python3.13/site-packages/sklearn/utils/validation.py:1405, in column_or_1d(y, dtype, input_name, warn, device)
#    1362 """Ravel column or 1d numpy array, else raises an error.
#    1363
#    1364 Parameters
#    (...)   1402 array([1, 1])
#    1403 """
#    1404 xp, _ = get_namespace(y)
# -> 1405 y = check_array(
#    1406     y,
#    1407     ensure_2d=False,
#    1408     dtype=dtype,
#    1409     input_name=input_name,
#    1410     ensure_all_finite=False,
#    1411     ensure_min_samples=0,
#    1412 )
#    1414 shape = y.shape
#    1415 if len(shape) == 1:
#
# File /opt/homebrew/Cellar/jupyterlab/4.4.7/libexec/lib/python3.13/site-packages/sklearn/utils/validation.py:1020, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1012     if xp.isdtype(array.dtype, ("real floating", "complex floating")):
#    1013         _assert_all_finite(
#    1014             array,
#    1015             allow_nan=False,
#    (...)   1018             input_name=input_name,
#    1019         )
# -> 1020     array = xp.astype(array, dtype, copy=False)
#    1021 else:
#    1022     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#
# File /opt/homebrew/Cellar/jupyterlab/4.4.7/libexec/lib/python3.13/site-packages/sklearn/externals/array_api_compat/numpy/_aliases.py:125, in astype(x, dtype, copy, device)
#     116 def astype(
#     117     x: Array,
#     118     dtype: DType,
#    (...)    122     device: Device | None = None,
#     123 ) -> Array:
#     124     _helpers._check_device(np, device)
# --> 125     return x.astype(dtype=dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: 'Male'

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
ct=ColumnTransformer(transformers=[('onehot')],OneHotEncoder(drop='first'),3),remainder='passthrough')
# Out:
#   Cell In[24], line 1
#     ct=ColumnTransformer(transformers=[('onehot')],OneHotEncoder(drop='first'),3),remainder='passthrough')
#                                                                                                          ^
# SyntaxError: unmatched ')'
